# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\softwares\python\lib\site-packages (2.7.0)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\softwares\python\lib\site-packages (from tensorflow) (1.43.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\softwares\python\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: keras<2.8,>=2.7.0rc0 in c:\softwares\python\lib\site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: tensorflow-estimator<2.8,~=2.7.0rc0 in c:\softwares\python\lib\site-packages (from tensorflow) (2.7.0)
# Requirement already satisfied: six>=1.12.0 in c:\softwares\python\lib\site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: tensorboard~=2.6 in c:\softwares\python\lib\site-packages (from tensorflow) (2.8.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\softwares\python\lib\site-packages (from tensorflow) (1.1.2)
#
# Requirement already satisfied: google-pasta>=0.1.1 in c:\softwares\python\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: gast<0.5.0,>=0.2.1 in c:\softwares\python\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: wheel<1.0,>=0.32.0 in c:\softwares\python\lib\site-packages (from tensorflow) (0.34.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.21.0 in c:\softwares\python\lib\site-packages (from tensorflow) (0.23.1)
# Requirement already satisfied: protobuf>=3.9.2 in c:\softwares\python\lib\site-packages (from tensorflow) (3.19.4)
# Requirement already satisfied: numpy>=1.14.5 in c:\softwares\python\lib\site-packages (from tensorflow) (1.21.2)
# Requirement already satisfied: h5py>=2.9.0 in c:\softwares\python\lib\site-packages (from tensorflow) (3.6.0)
# Requirement already satisfied: absl-py>=0.4.0 in c:\softwares\python\lib\site-packages (from tensorflow) (1.0.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\softwares\python\lib\site-packages (from tensorflow) (1.13.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\softwares\python\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\softwares\python\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: libclang>=9.0.1 in c:\softwares\python\lib\site-packages (from tensorflow) (13.0.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\softwares\python\lib\site-packages (from tensorflow) (4.0.1)
# Requirement already satisfied: flatbuffers<3.0,>=1.12 in c:\softwares\python\lib\site-packages (from tensorflow) (2.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\softwares\python\lib\site-packages (from tensorboard~=2.6->tensorflow) (3.3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\softwares\python\lib\site-packages (from tensorboard~=2.6->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\softwares\python\lib\site-packages (from tensorboard~=2.6->tensorflow) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\softwares\python\lib\site-packages (from tensorboard~=2.6->tensorflow) (2.0.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\softwares\python\lib\site-packages (from tensorboard~=2.6->tensorflow) (2.27.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\softwares\python\lib\site-packages (from tensorboard~=2.6->tensorflow) (41.2.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\softwares\python\lib\site-packages (from tensorboard~=2.6->tensorflow) (2.5.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\softwares\python\lib\site-packages (from tensorboard~=2.6->tensorflow) (1.8.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\softwares\python\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\softwares\python\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\softwares\python\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (4.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\softwares\python\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\softwares\python\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.6->tensorflow) (4.10.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\softwares\python\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.26.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\softwares\python\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.0.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\softwares\python\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\softwares\python\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (3.3)
# Requirement already satisfied: zipp>=0.5 in c:\softwares\python\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard~=2.6->tensorflow) (3.7.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\softwares\python\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard~=2.6->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\softwares\python\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (3.2.0)

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path('C:/Users/91938/OneDrive/Documents/Project_Skin_Cancer/Skin cancer ISIC The International Skin Imaging Collaboration/Train')
data_dir_test = pathlib.Path('C:/Users/91938/OneDrive/Documents/Project_Skin_Cancer/Skin cancer ISIC The International Skin Imaging Collaboration/Test')

# %%
pwd
# Out:
# 'C:\\Users\\91938\\AndroidStudioProjects\\MiniProject'

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 20239 files belonging to 9 classes.
# Using 16192 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 20239 files belonging to 9 classes.
# Using 4047 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list. 
# You can find the class names in the class_names attribute on these datasets. 
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %%
print(type(train_ds))
print(train_ds)
# Out:
# <class 'tensorflow.python.data.ops.dataset_ops.BatchDataset'>
# <BatchDataset shapes: ((None, 180, 180, 3), (None,)), types: (tf.float32, tf.int32)>

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 180, 180, 3)
# (32,)

# %% [raw]
# Visualize the data
# Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10))
i=0
for k in class_names:
  for images, labels in train_ds.unbatch().take(1793):
    if class_names[labels] == k:
      i=i+1
      ax = plt.subplot(3, 3, i)
      plt.imshow(images.numpy().astype("uint8"))
      plt.title(class_names[labels])
      plt.axis("off")
      break

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
##Create the model
##Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use layers.experimental.preprocessing.Rescaling to normalize pixel values between (0,1). The RGB channel values are in the [0, 255] range. This is not ideal for a neural network. Here, it is good to standardize values to be in the [0, 1]

# %%
num_classes = 9

model = tf.keras.Sequential([
  layers.experimental.preprocessing.Rescaling(1./255,input_shape=(img_width,img_height,3)),
  layers.Conv2D(32, 3, activation='relu'),
  layers.MaxPooling2D((2, 2)),
  layers.Conv2D(64, 3, activation='relu'),
  layers.MaxPooling2D((2, 2)),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, activation='softmax')
])

# %%
#Compile the model
#Choose an appropirate optimiser and loss function for model training

# %%
model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 89, 89, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 118336)            0
#
#  dense (Dense)               (None, 128)               15147136
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 15,167,689
# Trainable params: 15,167,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# c:\softwares\python\lib\site-packages\tensorflow\python\util\dispatch.py:1096: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# 506/506 [==============================] - 465s 814ms/step - loss: 1.5425 - accuracy: 0.4497 - val_loss: 1.0972 - val_accuracy: 0.5752
# Epoch 2/20
# 506/506 [==============================] - 455s 899ms/step - loss: 0.8553 - accuracy: 0.7013 - val_loss: 0.6878 - val_accuracy: 0.7638
# Epoch 3/20
# 506/506 [==============================] - 884s 2s/step - loss: 0.5152 - accuracy: 0.8238 - val_loss: 0.6814 - val_accuracy: 0.7534
# Epoch 4/20
# 506/506 [==============================] - 687s 1s/step - loss: 0.3585 - accuracy: 0.8774 - val_loss: 0.4258 - val_accuracy: 0.8592
# Epoch 5/20
# 506/506 [==============================] - 670s 1s/step - loss: 0.2771 - accuracy: 0.9047 - val_loss: 0.4293 - val_accuracy: 0.8601
# Epoch 6/20
# 506/506 [==============================] - 791s 2s/step - loss: 0.2253 - accuracy: 0.9209 - val_loss: 0.3978 - val_accuracy: 0.8671
# Epoch 7/20
# 506/506 [==============================] - 606s 1s/step - loss: 0.1736 - accuracy: 0.9356 - val_loss: 0.3390 - val_accuracy: 0.8841
# Epoch 8/20
# 506/506 [==============================] - 619s 1s/step - loss: 0.1846 - accuracy: 0.9314 - val_loss: 0.4151 - val_accuracy: 0.8723
# Epoch 9/20
# 506/506 [==============================] - 591s 1s/step - loss: 0.1823 - accuracy: 0.9347 - val_loss: 0.3721 - val_accuracy: 0.8802
# Epoch 10/20
# 506/506 [==============================] - 628s 1s/step - loss: 0.1328 - accuracy: 0.9489 - val_loss: 0.3270 - val_accuracy: 0.8997
# Epoch 11/20
# 506/506 [==============================] - 598s 1s/step - loss: 0.1399 - accuracy: 0.9466 - val_loss: 0.3653 - val_accuracy: 0.8997
# Epoch 12/20
# 506/506 [==============================] - 652s 1s/step - loss: 0.1575 - accuracy: 0.9407 - val_loss: 0.3776 - val_accuracy: 0.8831
# Epoch 13/20
# 506/506 [==============================] - 601s 1s/step - loss: 0.1412 - accuracy: 0.9468 - val_loss: 0.3707 - val_accuracy: 0.9041
# Epoch 14/20
# 506/506 [==============================] - 500s 987ms/step - loss: 0.1183 - accuracy: 0.9525 - val_loss: 0.5752 - val_accuracy: 0.8359
# Epoch 15/20
# 506/506 [==============================] - 2266s 4s/step - loss: 0.1565 - accuracy: 0.9439 - val_loss: 0.3752 - val_accuracy: 0.9046
# Epoch 16/20
# 506/506 [==============================] - 620s 1s/step - loss: 0.3252 - accuracy: 0.8896 - val_loss: 0.7287 - val_accuracy: 0.7892
# Epoch 17/20
# 506/506 [==============================] - 627s 1s/step - loss: 0.2079 - accuracy: 0.9263 - val_loss: 0.4864 - val_accuracy: 0.8883
# Epoch 18/20
# 506/506 [==============================] - 589s 1s/step - loss: 0.1144 - accuracy: 0.9552 - val_loss: 0.4007 - val_accuracy: 0.9019
# Epoch 19/20
# 506/506 [==============================] - 665s 1s/step - loss: 0.0964 - accuracy: 0.9589 - val_loss: 0.4281 - val_accuracy: 0.8935
# Epoch 20/20
# 506/506 [==============================] - 570s 1s/step - loss: 0.0918 - accuracy: 0.9609 - val_loss: 0.3839 - val_accuracy: 0.9044

# %%
#Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']


loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit
#Write your findings here
#Model is overfitting since training accuracy is 93% while validation accuracy is 52%

#Apply Data Augmentation

# %%
# Using data augmentation

from tensorflow.keras.preprocessing.image import ImageDataGenerator

image_size = 180
batch_size = 32

#Apply shear, zoom, horizontal flip of original images
train_data_gen = ImageDataGenerator(shear_range=0.2, zoom_range=0.2, 
                                    horizontal_flip=True)

#retrieving original training set
list_images = []
list_labels = []
for images, labels in train_ds.unbatch().take(-1):  
    list_images.append(images.numpy())
    list_labels.append(labels.numpy())

list_images = np.array(list_images)
list_labels = np.array(list_labels)

 #create augmented tensorflow data object
train_generator = train_data_gen.flow(list_images, list_labels,batch_size=batch_size)

# %%
## Method 2 - read from directory

from tensorflow.keras.preprocessing.image import ImageDataGenerator

image_size = 180
batch_size = 32

train_data_gen = ImageDataGenerator(
                             shear_range=0.2, zoom_range=0.2, 
                                    horizontal_flip=True, validation_split=0.2)

train_generator = train_data_gen.flow_from_directory(data_dir_train, (180,180),batch_size=batch_size, seed=123, subset='training',  class_mode='categorical')

image_batch, label_batch = next(iter(train_generator))

plt.figure(figsize=(10, 10))
for i in range(9):
  ax = plt.subplot(3, 3, i + 1)
  #plt.imshow(image_batch[i])
  plt.imshow(image_batch[i].astype('uint8'))

  label = label_batch[i] 
plt.axis("off")
# Out:
# Found 16195 images belonging to 9 classes.
# (-0.5, 179.5, 179.5, -0.5)

# %%
IMG_SIZE = 180

data_augmentation = keras.Sequential(
  [
    layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(IMG_SIZE, 
                                                              IMG_SIZE,
                                                              3)),
    layers.experimental.preprocessing.RandomRotation(0.1),      
  ]
)

# %%
for images, labels in train_ds.take(1):
  result = data_augmentation(images)
  aug_image_batch = next(iter(result))
  image_batch = next(iter(images))
  ax = plt.subplot(1, 2, 1)
  plt.imshow(aug_image_batch.numpy().astype("uint8"))
  plt.title(class_names[labels[0]])
  ax = plt.subplot(1, 2, 2)
  plt.imshow(image_batch.numpy().astype("uint8"))
  plt.title(class_names[labels[0]])

# %%
#Todo:
#Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

### Your code goes here
num_classes = 9

model = tf.keras.Sequential([
  layers.experimental.preprocessing.Rescaling(1./255,input_shape=(img_width,img_height,3)),
  data_augmentation,
  layers.Conv2D(32, 3, activation='relu'),
  layers.MaxPooling2D((2, 2)),
  layers.Dropout(0.1),
  layers.Conv2D(64, 3, activation='relu'),
  layers.MaxPooling2D((2, 2)),
  layers.Dropout(0.1),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, activation='softmax')
])

# %%
#Compiling the model

# %%
### Todo, choose an appropirate optimiser and loss function
### Todo, choose an appropirate optimiser and loss function
model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

# %%
#Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 506/506 [==============================] - 628s 1s/step - loss: 1.7231 - accuracy: 0.3677 - val_loss: 1.3518 - val_accuracy: 0.4972
# Epoch 2/20
# 506/506 [==============================] - 618s 1s/step - loss: 1.3194 - accuracy: 0.4970 - val_loss: 1.3124 - val_accuracy: 0.5120
# Epoch 3/20
# 506/506 [==============================] - 932s 2s/step - loss: 1.1707 - accuracy: 0.5624 - val_loss: 1.0946 - val_accuracy: 0.5992
# Epoch 4/20
# 506/506 [==============================] - 677s 1s/step - loss: 1.0466 - accuracy: 0.6126 - val_loss: 0.9333 - val_accuracy: 0.6575
# Epoch 5/20
# 506/506 [==============================] - 1579s 3s/step - loss: 0.9497 - accuracy: 0.6440 - val_loss: 0.9202 - val_accuracy: 0.6756
# Epoch 6/20
# 506/506 [==============================] - 562s 1s/step - loss: 0.8629 - accuracy: 0.6794 - val_loss: 0.8741 - val_accuracy: 0.6854
# Epoch 7/20
# 506/506 [==============================] - 1258s 2s/step - loss: 0.7774 - accuracy: 0.7109 - val_loss: 0.7109 - val_accuracy: 0.7366
# Epoch 8/20
# 506/506 [==============================] - 553s 1s/step - loss: 0.7261 - accuracy: 0.7297 - val_loss: 0.6708 - val_accuracy: 0.7581
# Epoch 9/20
# 506/506 [==============================] - 503s 994ms/step - loss: 0.6685 - accuracy: 0.7528 - val_loss: 0.6544 - val_accuracy: 0.7571
# Epoch 10/20
# 506/506 [==============================] - 7357s 15s/step - loss: 0.6285 - accuracy: 0.7716 - val_loss: 0.6119 - val_accuracy: 0.7821
# Epoch 11/20
# 506/506 [==============================] - 22928s 45s/step - loss: 0.5837 - accuracy: 0.7887 - val_loss: 0.5287 - val_accuracy: 0.8127
# Epoch 12/20
# 506/506 [==============================] - 746s 1s/step - loss: 0.5540 - accuracy: 0.7997 - val_loss: 0.5451 - val_accuracy: 0.8001
# Epoch 13/20
# 506/506 [==============================] - 759s 1s/step - loss: 0.5116 - accuracy: 0.8156 - val_loss: 0.5039 - val_accuracy: 0.8189
# Epoch 14/20
# 506/506 [==============================] - 972s 2s/step - loss: 0.4883 - accuracy: 0.8236 - val_loss: 0.4355 - val_accuracy: 0.8503
# Epoch 15/20
# 506/506 [==============================] - 518s 1s/step - loss: 0.4844 - accuracy: 0.8233 - val_loss: 0.4638 - val_accuracy: 0.8315
# Epoch 16/20
# 506/506 [==============================] - 1243s 2s/step - loss: 0.4555 - accuracy: 0.8389 - val_loss: 0.4149 - val_accuracy: 0.8498
# Epoch 17/20
# 506/506 [==============================] - 515s 1s/step - loss: 0.4387 - accuracy: 0.8417 - val_loss: 0.5089 - val_accuracy: 0.8251
# Epoch 18/20
# 506/506 [==============================] - 533s 1s/step - loss: 0.4156 - accuracy: 0.8492 - val_loss: 0.4176 - val_accuracy: 0.8485
# Epoch 19/20
# 506/506 [==============================] - 1440s 3s/step - loss: 0.4135 - accuracy: 0.8518 - val_loss: 0.3971 - val_accuracy: 0.8648
# Epoch 20/20
# 506/506 [==============================] - 783s 2s/step - loss: 0.3647 - accuracy: 0.8670 - val_loss: 0.3530 - val_accuracy: 0.8690

# %%
#Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
#Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?
#After data agumentation(train acc:70% val:56%) and dropouts, model became more general. Gap between train and val accuracy reduced a lot just by applying transformations to training images. Train accuracy 65% val accuracy = 55%. Still need to improve accuracy.

#Todo: Find the distribution of classes in the training dataset.
#Context: Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
import os
path = 'C:/Users/91938/OneDrive/Documents/Project_Skin_Cancer/Skin cancer ISIC The International Skin Imaging Collaboration/Train'
mn = 0
folders = ([name for name in os.listdir(path)if os.path.isdir(os.path.join(path, name))]) # get all directories 
for folder in folders:
    contents = os.listdir(os.path.join(path,folder)) # get list of contents
    if len(contents) >= mn: # if greater than the limit, print folder and number of contents
        plt.barh(folder,len(contents))

# %%
#Todo: Write your findings here:
#- Which class has the least number of samples?
#- Which classes dominate the data in terms proportionate number of samples?
#Pigmented benign keratosis, melanoma, basal cell carcnoma dominates proportionate number of samples. Seborrheic keratosis has least number of samples

#Todo: Rectify the class imbalance
#Context: You can use a python package known as Augmentor (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Requirement already satisfied: Augmentor in c:\softwares\python\lib\site-packages (0.2.9)
# Requirement already satisfied: tqdm>=4.9.0 in c:\softwares\python\lib\site-packages (from Augmentor) (4.63.1)
# Requirement already satisfied: numpy>=1.11.0 in c:\softwares\python\lib\site-packages (from Augmentor) (1.21.2)
# Requirement already satisfied: future>=0.16.0 in c:\softwares\python\lib\site-packages (from Augmentor) (0.18.2)
# Requirement already satisfied: Pillow>=5.2.0 in c:\softwares\python\lib\site-packages (from Augmentor) (8.4.0)
# Requirement already satisfied: colorama in c:\softwares\python\lib\site-packages (from tqdm>=4.9.0->Augmentor) (0.4.3)

# %%
path_to_training_dataset='C:/Users/91938/OneDrive/Documents/Project_Skin_Cancer/Skin cancer ISIC The International Skin Imaging Collaboration/Train/'
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none
# Out:
# Initialised with 114 image(s) found.
# Output directory set to C:/Users/91938/OneDrive/Documents/Project_Skin_Cancer/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis\output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x179AE0E3130>: 100%|████████████████████████████████████████████████████████████████████████| 500/500 [00:10<00:00, 47.05 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to C:/Users/91938/OneDrive/Documents/Project_Skin_Cancer/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x179B68C65E0>: 100%|██████████████████████████████████████████████████████████████████████████████████████████| 500/500 [00:07<00:00, 67.30 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to C:/Users/91938/OneDrive/Documents/Project_Skin_Cancer/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x179B6872370>: 100%|██████████████████████████████████████████████████████████████████████████████████████████| 500/500 [00:07<00:00, 65.01 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to C:/Users/91938/OneDrive/Documents/Project_Skin_Cancer/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma\output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x179B6784310>: 100%|█████████████████████████████████████████████████████████████████████████████████████████| 500/500 [00:38<00:00, 13.15 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to C:/Users/91938/OneDrive/Documents/Project_Skin_Cancer/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus\output.
# Processing <PIL.Image.Image image mode=RGB size=767x576 at 0x179B6B67970>: 100%|██████████████████████████████████████████████████████████████████████████████████████████| 500/500 [00:41<00:00, 12.06 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to C:/Users/91938/OneDrive/Documents/Project_Skin_Cancer/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x179ACE3D100>: 100%|██████████████████████████████████████████████████████████████████████████████████████████| 500/500 [00:07<00:00, 64.46 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to C:/Users/91938/OneDrive/Documents/Project_Skin_Cancer/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis\output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x17985C48880>: 100%|█████████████████████████████████████████████████████████████████████████████████████████| 500/500 [00:18<00:00, 26.95 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to C:/Users/91938/OneDrive/Documents/Project_Skin_Cancer/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma\output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x179B68C8850>: 100%|████████████████████████████████████████████████████████████████████████| 500/500 [00:07<00:00, 65.34 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to C:/Users/91938/OneDrive/Documents/Project_Skin_Cancer/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion\output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x17985C48880>: 100%|██████████████████████████████████████████████████████████████████████████████████████████| 500/500 [00:07<00:00, 66.82 Samples/s]

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 22500

# %%
#Lets see the distribution of augmented data after adding new images to the original training data.

# %%
from glob import glob
path_list_new = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list_new[1]
# Out:
# 'C:\\Users\\91938\\OneDrive\\Documents\\Project_Skin_Cancer\\Skin cancer ISIC The International Skin Imaging Collaboration\\Train\\actinic keratosis\\output\\actinic keratosis_original_ISIC_0025780.jpg_396478eb-9438-46d0-a4de-cd981005f688.jpg'

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new[1]
# Out:
# 'actinic keratosis'

# %%
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
path_list = [x for x in glob(os.path.join(data_dir_train, '*', '*.jpg'))]
lesion_list = [os.path.basename(os.path.dirname(y)) for y in glob(os.path.join(data_dir_train, '*', '*.jpg'))]
dataframe_dict = dict(zip(path_list, lesion_list))
original_df = pd.DataFrame(list(dataframe_dict.items()),columns = ['Path','Label'])

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = original_df.append(df2)

# %%
new_df['Label'].value_counts()
# Out:
# pigmented benign keratosis    2962
# melanoma                      2938
# basal cell carcinoma          2876
# nevus                         2857
# squamous cell carcinoma       2681
# vascular lesion               2639
# actinic keratosis             2614
# dermatofibroma                2595
# seborrheic keratosis          2577
# Name: Label, dtype: int64

# %%
#So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

#Todo: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %%
#Todo: Create a training dataset

# %%
#data_dir_train="path to directory with training data + data created using augmentor"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 24739 files belonging to 9 classes.
# Using 19792 files for training.

# %%
#Todo: Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 24739 files belonging to 9 classes.
# Using 4947 files for validation.

# %%
#Todo: Create your model (make sure to include normalization)

# %%
### Your code goes here
num_classes = 9

model = tf.keras.Sequential([
  layers.experimental.preprocessing.Rescaling(1./255,input_shape=(img_width,img_height,3)),
  data_augmentation,
  layers.Conv2D(32, 3, activation='relu'),
  layers.MaxPooling2D((2, 2)),
  layers.Dropout(0.1),
  layers.Conv2D(64, 3, activation='relu'),
  layers.MaxPooling2D((2, 2)),
  layers.Dropout(0.1),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, activation='softmax')
])

# %%
#Todo: Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here
model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

# %%
#Todo: Train your model

# %%
#result="skincancer.h5"


epochs = 30
## Your code goes here, use 50 epochs.
history = history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)

#model=load_model(result)
# Out:
# Epoch 1/30
# 619/619 [==============================] - 912s 1s/step - loss: 1.1887 - accuracy: 0.5540 - val_loss: 1.0924 - val_accuracy: 0.5981
# Epoch 2/30
# 619/619 [==============================] - 892s 1s/step - loss: 1.0546 - accuracy: 0.6103 - val_loss: 0.9633 - val_accuracy: 0.6448
# Epoch 3/30
# 619/619 [==============================] - 836s 1s/step - loss: 0.9258 - accuracy: 0.6565 - val_loss: 0.9002 - val_accuracy: 0.6653
# Epoch 4/30
# 619/619 [==============================] - 730s 1s/step - loss: 0.8680 - accuracy: 0.6782 - val_loss: 0.7611 - val_accuracy: 0.7277
# Epoch 5/30
# 619/619 [==============================] - 1337s 2s/step - loss: 0.7653 - accuracy: 0.7178 - val_loss: 0.6950 - val_accuracy: 0.7558
# Epoch 6/30
# 619/619 [==============================] - 673s 1s/step - loss: 0.6905 - accuracy: 0.7469 - val_loss: 0.6391 - val_accuracy: 0.7669
# Epoch 7/30
# 619/619 [==============================] - 892s 1s/step - loss: 0.6616 - accuracy: 0.7613 - val_loss: 0.5942 - val_accuracy: 0.7841
# Epoch 8/30
# 619/619 [==============================] - 906s 1s/step - loss: 0.6166 - accuracy: 0.7805 - val_loss: 0.5286 - val_accuracy: 0.8059
# Epoch 9/30
# 619/619 [==============================] - 733s 1s/step - loss: 0.5718 - accuracy: 0.7916 - val_loss: 0.5274 - val_accuracy: 0.8039
# Epoch 10/30
# 619/619 [==============================] - 808s 1s/step - loss: 0.5362 - accuracy: 0.8060 - val_loss: 0.4764 - val_accuracy: 0.8229
# Epoch 11/30
# 619/619 [==============================] - 906s 1s/step - loss: 0.5035 - accuracy: 0.8189 - val_loss: 0.4700 - val_accuracy: 0.8268
# Epoch 12/30
# 619/619 [==============================] - 745s 1s/step - loss: 0.4645 - accuracy: 0.8312 - val_loss: 0.5301 - val_accuracy: 0.8080
# Epoch 13/30
# 619/619 [==============================] - 645s 1s/step - loss: 0.4655 - accuracy: 0.8325 - val_loss: 0.3959 - val_accuracy: 0.8593
# Epoch 14/30
# 619/619 [==============================] - 693s 1s/step - loss: 0.4357 - accuracy: 0.8420 - val_loss: 0.4310 - val_accuracy: 0.8413
# Epoch 15/30
# 619/619 [==============================] - 719s 1s/step - loss: 0.4390 - accuracy: 0.8438 - val_loss: 0.4082 - val_accuracy: 0.8528
# Epoch 16/30
# 619/619 [==============================] - 714s 1s/step - loss: 0.4151 - accuracy: 0.8517 - val_loss: 0.4472 - val_accuracy: 0.8371
# Epoch 17/30
# 619/619 [==============================] - 727s 1s/step - loss: 0.3948 - accuracy: 0.8589 - val_loss: 0.3984 - val_accuracy: 0.8625
# Epoch 18/30
# 619/619 [==============================] - 712s 1s/step - loss: 0.3899 - accuracy: 0.8557 - val_loss: 0.3968 - val_accuracy: 0.8629
# Epoch 19/30
# 619/619 [==============================] - 608s 982ms/step - loss: 0.3718 - accuracy: 0.8661 - val_loss: 0.3514 - val_accuracy: 0.8771
# Epoch 20/30
# 619/619 [==============================] - 3529s 6s/step - loss: 0.3595 - accuracy: 0.8715 - val_loss: 0.3610 - val_accuracy: 0.8777
# Epoch 21/30
# 619/619 [==============================] - 2353s 4s/step - loss: 0.3765 - accuracy: 0.8639 - val_loss: 0.3539 - val_accuracy: 0.8714
# Epoch 22/30
# 619/619 [==============================] - 590s 953ms/step - loss: 0.3492 - accuracy: 0.8733 - val_loss: 0.3479 - val_accuracy: 0.8785
# Epoch 23/30
# 619/619 [==============================] - 649s 1s/step - loss: 0.3736 - accuracy: 0.8690 - val_loss: 0.3325 - val_accuracy: 0.8828
# Epoch 24/30
# 619/619 [==============================] - 642s 1s/step - loss: 0.3281 - accuracy: 0.8838 - val_loss: 0.3556 - val_accuracy: 0.8759
# Epoch 25/30
# 619/619 [==============================] - 2039s 3s/step - loss: 0.3134 - accuracy: 0.8844 - val_loss: 0.2886 - val_accuracy: 0.8991
# Epoch 26/30
# 619/619 [==============================] - 1568s 3s/step - loss: 0.2988 - accuracy: 0.8901 - val_loss: 0.3098 - val_accuracy: 0.8921
# Epoch 27/30
# 619/619 [==============================] - 2668s 4s/step - loss: 0.2899 - accuracy: 0.8940 - val_loss: 0.2790 - val_accuracy: 0.9020
# Epoch 28/30
# 619/619 [==============================] - 895s 1s/step - loss: 0.3070 - accuracy: 0.8874 - val_loss: 0.2916 - val_accuracy: 0.9018
# Epoch 29/30
# 619/619 [==============================] - 948s 2s/step - loss: 0.3041 - accuracy: 0.8918 - val_loss: 0.3113 - val_accuracy: 0.8844
# Epoch 30/30
# 619/619 [==============================] - 971s 2s/step - loss: 0.3039 - accuracy: 0.8933 - val_loss: 0.2859 - val_accuracy: 0.9050

# %%
#Todo: Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model.evaluate(val_ds)
# Out:
# 155/155 [==============================] - 43s 272ms/step - loss: 0.2859 - accuracy: 0.9050
# [0.285923033952713, 0.904992938041687]

# %%
Todo: Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?
Overfitting issue resolved by data augmentation and dropouts.
Accuracy is improved by adding 500 images for each class reducing class imbalance. Train accuracy : 78.6% Validation accuracy : 73%
Reducing class imbalance helped model learnt features of each class with comparable weightage.
Data augmentation helped model learnt different variations of classes thus not mugging up train data.
